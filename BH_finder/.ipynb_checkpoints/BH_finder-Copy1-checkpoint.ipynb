# %%
import pynbody
import matplotlib.pylab as plt
import numpy as np
# %matplotlib inline

# %%
pynbody.load('/data/scratch/jillian/h148/h148.cosmo50PLK.3072g3HbwK1BH.004096/h148.cosmo50PLK.3072g3HbwK1BH.004096')
s.physical_units();
h=s.halos()

# %%
BH=s.star[pynbody.filt.BandPass('tform','-15 Gyr','0 Gyr')]
BH_pos=BH['pos']
nBH=len(BH['iord'])

# %%
grpid=1; w=100;

# %%
pynbody.analysis.halo.center(h[grpid]);
#pynbody.analysis.angmom.faceon(h[grpid], cen=(0,0,0));

# %%
h[grpid].s['tform'].convert_units('Gyr')

# %%
pynbody.plot.image(h[grpid].s,qty="tform",cmap="Greys", width=w, log=False); plt.plot(np.array((BH[np.where(BH['amiga.grp']==grpid)]['pos'])).T[0],np.array((BH[np.where(BH['amiga.grp']==grpid)]['pos'])).T[1],'r+'); plt.xlim(-w/2,w/2); plt.ylim(-w/2,w/2);
plt.savefig('h%s_tform_w%s.png'%(grpid,w))

# %%
pynbody.plot.image(h[grpid].s,qty='tform_scaled',width=w,cmap="PRGn", log=False);
plt.plot(np.array((BH[np.where(BH['amiga.grp']==grpid)]['pos'])).T[0],np.array((BH[np.where(BH['amiga.grp']==grpid)]['pos'])).T[1],'r+')
plt.xlim(-w/2,w/2)
plt.ylim(-w/2,w/2);
plt.savefig('h%s_tform_w%s_scaled.png'%(grpid,w))

# %%
from sklearn.preprocessing import scale

# %%
tform_array=scale(s.star['tform'])
s.star['tform_scaled']=tform_array;

# %%
BH['amiga.grp']

# %%
pynbody.plot.image(h[grpid].s,qty="tform",cmap="Greys", log=False, width=w);
plt.plot(np.array((BH[np.where(BH['amiga.grp']==grpid)]['pos'])).T[0],np.array((BH[np.where(BH['amiga.grp']==grpid)]['pos'])).T[1],'r+');

# %%
len(set(s.star['amiga.grp']))

# %%
np.unique(s.star['amiga.grp'])

# %%
plot_BH_pos(1,100,False)
