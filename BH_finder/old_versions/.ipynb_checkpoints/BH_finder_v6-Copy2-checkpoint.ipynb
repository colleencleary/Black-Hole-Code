# %%
import pynbody
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
import BH_functions as bhf
# %matplotlib inline
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#galaxy_masses=pd.DataFrame()
#BH_halos=pd.DataFrame()
snap_id=0
global iords
iords=pd.read_csv('csvdata/iords.csv',index_col='snap')

# %%
#array of last four digits for each snap
snap_id_array=['0139','0225','0275','0640','0974','1024','1269','1280','1408','1740','2048','2088','2432','2688','2816','2944','3072','3195','3200','3328','3456','3584','3606','3712','3840','3968','4096']

# %%
#snap id index (negative values start from end)
snap_id=-1
snap_id_array[snap_id]
# Out:
# '4096'

# %%
snap_lowz, h_lowz, BH_lowz, BH_arm_lowz=do_all(snap_id_array[snap_id])
# Out:
# BH_arm iords: [101863565 101863739 101863883 101864796 101867516]

# %%
masses,iords=load_snap_csvs(snap_id_array[snap_id])
global iords_list
iords_list=iords.columns.tolist()
iords_list=map(int, iords_list)
time=pd.read_csv('csvdata/time.csv', index_col=0)
global time_axis
time_axis=pd.read_csv('csvdata/time_axis.csv', index_col=0)

# %%
for i in BH_arm_lowz['iord']:
    vars()['i_%s_data'%(i)]=pd.read_csv('csvdata/iord_%s.csv'%(i),index_col='snap')
    vars()['adj_i%s_orbit'%(i)]=pd.read_csv('~/adj_i%s_orbit.csv'%(i))

# %%
analysis(h_lowz[1], 'asis')

# %%
halo_id, span, halos, BHlocal=bhplotfilter(snap_lowz, 200, BH_lowz, 1)
# Out:
# Currently centered on Halo 1
# Halo 1 BH iord(s): [101863510 101863726 101863732 101865286 101865398 101866127]
#
#
# Halos within 100 kpc: [1, 64, 466, 874]
# Local BH_iord(s): [101863510, 101863726, 101863732, 101865286, 101866127]

# %%
halo_id, span, halos, BHlocal=bhplotfilter(snap_lowz, 200, BH_lowz, 64)
# Out:
# Currently centered on Halo 64
# Halo 64 BH iord(s): []
#
#
# Halos within 100 kpc: [1, 64, 77, 466, 874]
# Local BH_iord(s): [101863510, 101863726, 101863732, 101865286, 101866127]

# %%
bhf.render(snap_lowz,width=25)
#plt.savefig('presentation_images/maybe4.png', dpi=1600,figsize=(20,20))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-265-19a77d015242> in <module>()
# ----> 1 bhf.render(snap_lowz,width=25)
#       2 #plt.savefig('presentation_images/maybe4.png', dpi=1600,figsize=(20,20))
#
# /data/scratch/ccleary/BH_finder/BH_functions.py in render(sim, filename, r_band, g_band, b_band, r_scale, g_scale, b_scale, dynamic_range, mag_range, width, starsize, plot, axes, ret_im, clear, ret_range)
#      99        *axes*: matplotlib axes object (deault: None)
#     100          if not None, the axes object to plot to
# --> 101
#     102        *dynamic_range*: float (default: 2.0)
#     103          The number of dex in luminosity over which the image brightness ranges
#
# NameError: global name 'convert_to_mag_arcsec2' is not defined

# %%
fig=plt.figure(dpi=1200,figsize=(6,4))
fig.figimage(image)
fig.savefig('presentation_images/fig2.png')

# %%
plot_all(i_101864796_data, adj_i101864796_orbit, time)#, save=True, filename='presentation_images/SMALLerrrr_h%s_plots.png')
plt.savefig('h11.png', dpi=1600, figsize=(6,6))

# %%
BH_arm_lowz['iord']
# Out:
# SimArray([101863565, 101863739, 101863883, 101864796, 101867516])
